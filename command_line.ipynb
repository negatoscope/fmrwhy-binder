% %%
fmrwhy_workflow_qc('fmrwhy_settings_ds002748.m')
% Out:
% options =
%
%   scalar structure containing the fields:
%
%     fmrwhy_dir =
%     spm_dir = /home/jovyan/spm12
%     bidsmatlab_dir = /home/jovyan/bids-matlab
%     dicm2nii_dir = /home/jovyan/dicm2nii
%     tapasphysio_dir = /home/jovyan/tapas
%     raincloud_dir = /home/jovyan/raincloudplots/tutorial_matlab
%     bids_dir = ds002748-download/
%     subjects_output =
%     {
%       [1,1] = 01
%     }
%     anat_template_session =
%     template_task = rest
%     template_session =
%     template_run =
%     template_echo =
%     TR =  2.5000
%     N_slices =  25
%     Ndummies = 0
%     Nscans =  100
%     TE = [](0x0)
%     map_rois = 0
%     roi_orig_dir = /Users/jheunis/Desktop/sample-data/NEUFEPME_data_templates
%     roi =
%
%       scalar structure containing the fields:
%
%         motor =
%
%           scalar structure containing the fields:
%
%             orig_fn: 2x1 cell
%             name: 1x2 cell
%             desc: 1x2 cell
%
%         emotion =
%
% ...
